# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path


#import pickle
import joblib # 讀取train_fraud_model.py 所儲存檔案內容

import xgboost as xgb
from joblib import PrintTime
from pandas import to_datetime, read_excel
from pandas.core.interchange.dataframe_protocol import DataFrame
from scipy.stats import quantile
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score,roc_curve, precision_recall_curve,average_precision_score
#from sklearn.metrics import confusion_matrix
#from sklearn.metrics import average_precision_score
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
#from xgboost.dask import predict

# %%
os.getcwd()
# Out:
# 'D:\\數據分析科\\鷹眼\\workspace\\code'

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %%
CRM_df = pd.read_csv(r'C:\Users\b003087\Downloads\營業部資料查詢紀錄_明細清單匯出結果202608.csv')
CRM_df = CRM_df.copy()

# %%
CRM_df.info()
print(CRM_df.shape)
CRM_df.head()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 938 entries, 0 to 937
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   序號      938 non-null    int64
#  1   查詢客戶統編  687 non-null    str
#  2   行員名稱    938 non-null    str
#  3   功能查詢資料  938 non-null    str
#  4   傳入參數    938 non-null    str
#  5   登入IP    938 non-null    str
#  6   執行時間    938 non-null    str
# dtypes: int64(1), str(6)
# memory usage: 51.4 KB
# (938, 7)
#    序號 查詢客戶統編            行員名稱  \
# 0   1    NaN  002767_方雅亭
# 1   2    NaN  002767_方雅亭
# 2   3    NaN  002767_方雅亭
# 3   4    NaN  002767_方雅亭
# 4   5    NaN  002767_方雅亭
#
#                                                                         功能查詢資料  \
# 0             [PrinterAction]USER_ACTION__PR_GROUP_CONTRIBUTION -列印報表_集團戶貢獻度報表
# 1                    [Group]USP_LAYOUT_GROUP_CONTRIBUTION -集團戶/關係戶客戶查詢_貢獻度查詢管理
# 2                    [Group]USP_LAYOUT_GROUP_CONTRIBUTION -集團戶/關係戶客戶查詢_貢獻度查詢管理
# ...

# %%
CRM_df['執行日期'] = pd.to_datetime(CRM_df['執行時間'])
# Out:
# C:\Users\b003087\AppData\Local\Temp\ipykernel_36260\74594442.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   CRM_df['執行日期'] = pd.to_datetime(CRM_df['執行時間'])
# ---------------------------------------------------------------------------
# DateParseError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 CRM_df['執行日期'] = pd.to_datetime(CRM_df['執行時間'])
#
# File ~\PyCharmMiscProject\.venv\Lib\site-packages\pandas\core\tools\datetimes.py:1040, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, origin, cache)
#    1038         result = arg.map(cache_array)
#    1039     else:
# -> 1040         values = convert_listlike(arg._values, format)
#    1041         result = arg._constructor(values, index=arg.index, name=arg.name)
# ...

# %%
CRM_df.groupby(['行員名稱','行員名稱',])
